# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_excel("./drive/MyDrive/Food_Price_Prediction/food_data.xlsx")

# %%
df.head(20)
# Out:
#                  food_name  rating  food_price                   vendor  \
# 0               beef_bhuna     3.9         229           Shopnar Shopno
# 1                egg_omlet     3.9          57           Shopnar Shopno
# 2             special_naan     4.3          30  Star Kabab & Restaurant
# 3   deshi_chicken_jhal_fry     4.3         140  Star Kabab & Restaurant
# 4           basmati_kacchi     4.3         460            Sultan's dine
# 5              morog_polao     4.3         299            Sultan's dine
# 6            mutton_tehari     4.3         230            Sultan's dine
# 7              beef_rezala     4.3         200            Sultan's dine
# 8            chicken_roast     4.3         150            Sultan's dine
# 9               jali_kabab     4.3          60            Sultan's dine
# 10             plain_polao     4.3         120            Sultan's dine
# 11                   firni     4.3          70            Sultan's dine
# 12                 borhani     4.3          70            Sultan's dine
# 13          zafrani_sarbat     4.3          90            Sultan's dine
# 14          basmati_kacchi     4.3         290              Kacchi Bhai
# 15         chui_jhal_gosto     4.3         160              Kacchi Bhai
# 16             plain_polao     4.3         120              Kacchi Bhai
# 17             beef_rezala     4.3         200              Kacchi Bhai
# 18           chicken_roast     4.3         150              Kacchi Bhai
# 19              jali_kabab     4.3          60              Kacchi Bhai
#
#            location cuisine_type main_ingridinet  serving_size
# 0        Shewrapara        local            beef           NaN
# 1        Shewrapara        local             egg           NaN
# 2            Banani        local           flour           NaN
# 3            Banani        local         chicken           NaN
# 4   Bashundhara R/A     biriyani          mutton           NaN
# 5   Bashundhara R/A     biriyani         chicken           NaN
# 6   Bashundhara R/A     biriyani          mutton           NaN
# 7   Bashundhara R/A        local            beef           NaN
# 8   Bashundhara R/A        local         chicken           NaN
# 9   Bashundhara R/A        local            beef           NaN
# 10  Bashundhara R/A        local            rice           NaN
# 11  Bashundhara R/A      dessert            rice           NaN
# 12  Bashundhara R/A     beverage          yogurt           NaN
# 13  Bashundhara R/A     beverage          yogurt           NaN
# 14  Bashundhara R/A     biriyani          mutton           NaN
# 15  Bashundhara R/A        local            beef           NaN
# 16  Bashundhara R/A        local            rice           NaN
# 17  Bashundhara R/A        local            beef           NaN
# 18  Bashundhara R/A        local         chicken           NaN
# 19  Bashundhara R/A        local            beef           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   food_name        699 non-null    object
#  1   rating           699 non-null    float64
#  2   food_price       699 non-null    int64
#  3   vendor           699 non-null    object
#  4   location         699 non-null    object
#  5   cuisine_type     699 non-null    object
#  6   main_ingridinet  699 non-null    object
#  7   serving_size     0 non-null      float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 43.8+ KB

# %%
df.shape
# Out:
# (699, 8)

# %%
df.describe()
# Out:
#            rating   food_price  serving_size
# count  699.000000   699.000000           0.0
# mean     4.186695   314.935622           NaN
# std      0.351473   233.685374           NaN
# min      3.000000    18.000000           NaN
# 25%      4.000000   165.000000           NaN
# 50%      4.300000   250.000000           NaN
# 75%      4.500000   397.000000           NaN
# max      4.700000  2600.000000           NaN

# %%
df.isnull().any()
# Out:
# food_name          False
# rating             False
# food_price         False
# vendor             False
# location           False
# cuisine_type       False
# main_ingridinet    False
# serving_size        True
# dtype: bool

# %%
df.drop('serving_size', axis=1, inplace=True)

# %%
df.isnull().any()
# Out:
# food_name          False
# rating             False
# food_price         False
# vendor             False
# location           False
# cuisine_type       False
# main_ingridinet    False
# dtype: bool

# %%
df.describe()
# Out:
#            rating   food_price
# count  699.000000   699.000000
# mean     4.186695   314.935622
# std      0.351473   233.685374
# min      3.000000    18.000000
# 25%      4.000000   165.000000
# 50%      4.300000   250.000000
# 75%      4.500000   397.000000
# max      4.700000  2600.000000

# %% [markdown]
# **Importing libraries**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.pairplot(df)

# %% [markdown]
# Separating numeric and categoric columns

# %%
number_col = df.select_dtypes('number')
categoric_col = df.select_dtypes('O')
for cat in categoric_col.columns:
  print(categoric_col[cat].unique())
# Out:
# ['beef_bhuna' 'egg_omlet' 'special_naan' 'deshi_chicken_jhal_fry'
#  'basmati_kacchi' 'morog_polao' 'mutton_tehari' 'beef_rezala'
#  'chicken_roast' 'jali_kabab' 'plain_polao' 'firni' 'borhani'
#  'zafrani_sarbat' 'chui_jhal_gosto' 'badam_sarbat' 'jorda'
#  'big_king_chicken' "chick'N_crisp" 'creamy_cheese_burger'
#  'crispy_king_chicken_burger' 'double_whopper' 'fish_n_crisp_burger'
#  'incredible_crispy_king' 'long_cheese_burger' 'long_chicken'
#  'premium_salmon_burger' 'quad_beef_stacker' 'salmon_caramelized_burger'
#  'tartar_crispy_chicken_burger' 'tendercrisp' 'triple_beef_stacker'
#  'triple_whopper_cheese' 'whopper' 'fish_n_crisp_burrito'
#  'crispy_chicken_salad' 'crunchy_garden_salad' 'chicken_tenders'
#  'crispy_fried_chicken' 'chicken_nuggets' 'fish_n_fries' 'fish_n_rice'
#  'french_fries' 'biriyani' 'cheddar_cream' 'mac_n_cheese' 'tender_beef'
#  'deep_sea_fantasy' 'four_flavour' 'bbq_meat_machine' 'kebab_cocktail'
#  'meat_masala' 'meaty_onion' 'suasage_carnival' 'bbq_beef_burger'
#  'cheese_beef_burger' 'juicy_beef_burger' 'bbq_chicken_burger'
#  'cheese_chicken_burger' 'juicy_chicken_burger' 'chicken_lolipop' 'bhaji'
#  'tea' 'chicken_fry' 'khichuri' 'mug_dal' 'mutton_bhuna' 'nihari'
#  'paratha' 'ruti' 'soup' 'ayer_fish' 'baila_fish' 'begun_vaji' 'rice'
#  'boal_fish' 'chicken_biriyani' 'prawn' 'chana_daal' 'dhoniya_pata_vorta'
#  'egg_vorta' 'yogurt' 'korolla_vaji' 'lal_shak' 'lau' 'rui_fish'
#  'rupchada_fish' 'naan' 'beef_sheek_kabab' 'chicken_chap'
#  'chicken_shawarma' 'chicken_tikka' 'grilled_chicken' 'haleem'
#  'mutton_boti_kabab' 'nawabi_kabab' 'faluda' 'chiken_burger'
#  'tanduri_burger' 'maxican_burger' 'crispy_chicken_bucket' 'chicken_wings'
#  'chicken_burger' 'chicken_cheese_burger' 'smokey_bbq_burger'
#  'doublex_chicken_burger' 'bbq_blast_pizza' 'maxican_pizza'
#  'sausage_pool_pizza' 'four_seasons_pizza' 'baked_chicken_pasta'
#  'maxican_pasta' 'naga_pasta' 'tandoori_pasta' 'potato_wedges'
#  'sour-wings' 'sriracha_wings' 'bbq_chicken_wings' 'naga_chicken_wings'
#  'chocolate_cold_coffee' 'caramel_cold_coffee' 'mango_smoothie'
#  'orange_smoothie' 'beef_cheese_burger' 'beef_cheese_delight'
#  'chicken_got_fried' 'panda_katsu_burger' 'chicken_classic_pan'
#  'double_cheese_pan' 'beef_lover_pan' 'bbq_pan' 'the_works_pan'
#  'bbq_chicken_pizza' 'beef_bacon_burger' 'chicken_sausage_burger'
#  'mushroom_chicken_burger' 'mushroom_beef_burger' 'peri_peri_french_fries'
#  'buffalo_wings' 'crispy_chicken_wings' 'peri_peri_wings'
#  'chicken_steak_burger' 'spicy_steak_burger' 'green_chili_chicken_burger'
#  'chicken_bbq_cheese_burger' 'chicken_naga_burger' 'twist_chicken_burger'
#  'naga_cheese_burger' 'premium_chicken_burger' 'double_cheese_burger'
#  'chicken_honey_blast_burger' 'chicken_giant_burger' 'special_burger'
#  'regular_beef_burger' 'beef_naga_burger' 'beef_naga_special_burger'
#  'beef_bbq_burger' 'beef_cheese_naga_special' 'beef_double_patty_burger'
#  'beef_cheese_king_burger' 'beef_sausage_burger' 'beef_honey_blast_burger'
#  'beef_special_burger' 'beef_giant_burger' 'fat_boy_beef_burger'
#  'french_fries_spicy' 'chicken_bbq_wings' 'chicken_fried_wings'
#  'naga_wings' 'strawberry_shake' 'nutella_shake' 'kitkat_shake'
#  'snickers_shake' 'sarda_pizza' 'margherita_pizza' 'americana_pizza'
#  'creamy_melt_pizza' 'cheesy_peperoni_pizza' 'mushroom_chicken_pizza'
#  'naga_pizza' 'bread_roll' 'chocolate_berliner' 'grilled_chicken_sandwich'
#  'chocolate_eclair' 'bluberry_chocolate_mousse' 'mini_pizza'
#  'vegetable_cheese_loaf' 'meatloaf' 'chicken_sausage_sandwich'
#  'white_chocolate_berliner' 'strawberry_berliner' 'chocolate_doughnut'
#  'strawberry_doughnut' 'vanilla_doughnut' 'croissant' 'blueberry_mousse'
#  'chocolate_pastry' 'red_velvet_pastry' 'chocolate_muffin'
#  'vanilla_muffin' 'caramel_eclair' 'cream_bun' 'chocolate_bun' 'lemon_bun'
#  'chicken_bacon_burger' 'chicken_signature_burger'
#  'gignato_chicken_burger' 'beef_burger' 'double_decker_beef_burger'
#  'beef_signature' 'chicken_strips' 'fish_finger' 'fried_wonton'
#  'spring_roll' 'chicken_corn_soup' 'chicken_vegetable_soup'
#  'thai_hot_soup' 'mushroom_soup' 'seafood_soup' 'cashewnut_salad'
#  'chicken_salad' 'shrimp_salad' 'seafood_salad' 'beef_shawarma'
#  'beef_wrap' 'shawarma_alfresco' 'pad_thai' 'american_chopsuey'
#  'beef_chopsuey' 'chicken_chopsuey' 'chicken_pasta' 'pasta_basta'
#  'pasta_bbq' 'pasta_veg' 'garlic_prawn' 'whole_pomfret_fish' 'fried_prawn'
#  'fried_calamari' 'fish_n_chips' 'dory_fish' 'crab' 'cuttle_fish'
#  'fish_sizzling' 'chicken_sizzling' 'mushroom_chicken'
#  'sweet_sour_chicken' 'thai_fried_chicken' 'beef_sizzling'
#  'long_bean_beef' 'beef_red_curry' 'beef_pizza' 'mexicano_pizza'
#  'pizza_italiano' 'masala_rice' 'thai_fried_rice' 'veg_fried_rice'
#  'special_fried_rice' 'egg_fried_rice' 'seafood_fried_rice'
#  'chocolate_mousse' 'oero_cheese_cake' 'black_forest' 'tiramisu'
#  'chocolate_ice_cream' 'vanilla_ice_cream' 'double_layer_cheese_cake'
#  'strawberry_icecream' 'mango_ice_cream' 'pineapple_margarita'
#  'blue_ocean' 'virjin_mojito' 'orange_mojito' 'malta_juice'
#  'green_mango_jouce' 'lemonade' 'mango_juice' 'papaya_juice'
#  'pineapple_juice' 'cold_coffee' 'hot_coffee' 'mocha' 'iced_tea'
#  'iced_mocha' 'hot_chocolate' 'pasta_carbonara' 'lasagna'
#  'pasta_vegetable' 'pasta_penne' 'pasta_chicken' 'pasta_beef'
#  'pasta_bolognese' 'crispy_chicken_pizza' 'mighty_meat_pizza'
#  'chicken_alfredo_pizza' 'grilled_chiicken_pizza' 'sweet_chill_pizza'
#  'chicken_fajita_pizza' 'roasted_garlic_chicken_pizza' 'hawaiian_pizza'
#  'meaty_max_pizza' 'cheese_lover_pizza' 'special_pizza'
#  'veggie_supreme_pizza' 'zesty_hot_pizza' 'classic_veggie_pizza'
#  'super_spicy_pizza' 'chicken_delight_pizza' 'gulliver_pizza'
#  'chicken_tandoori_pizza' 'deep_dish_pizza' 'pepperoni_pizza'
#  'seafood_clear_soup' 'creamy_mashroom_soup' 'vegetable_clear_soup'
#  'thai_clear_soup' 'thai_soup' 'chittagong_pizza' 'seafood_de_palermo'
#  'veg_corleony_pizza' 'italian_classics_pizza' 'pizza_volcano'
#  'pepperoni_de_panago' 'naples_unique' 'barcode_premium_pizza'
#  'pizza_de_amigo' 'pizza_de_fungi' 'sicilian_delight'
#  'bolognese_classic_pizza' 'beef_sausage' 'milan_supreme_pizza'
#  'romanian_delight' 'peccoraci_supreme' 'pizza_de_prosciutto'
#  'margarita_pizza' 'Beef Kacci' 'Hyderabadi Biriyani'
#  'Mutton dom Biriyani' 'Beef dom Biriyani' 'Chicken dom Biriyani'
#  'Bashmoti & chicken kosha' 'Beef lal Bhuna ' 'Beef kala Bhuna'
#  'Beef Cui Jhal' 'Duck Curry' 'Mutton jhal fry' 'Chicken Jhal fry'
#  'Chicken Roast' 'Boal Fish Bhuna' 'Rui fish bhuna' 'Pabda fish bhuna '
#  'Prawn bhuna ' 'Koel Roast' 'Sorisha Elish' 'Rupchada Fry'
#  'Chicken Kosha ' 'Beff booter dal' 'Vat' 'Khuder vat' 'Bashmoti vat'
#  'Plain Polao' 'Plain khicuri' 'Nimbu Pani' 'Borhani' 'Grill (Full)'
#  'Chiken Chap' 'Chicken Level too' 'Chicken Dhaturi(full)'
#  'Chicken Saslik' 'Mutton Leg Roast' 'Beef bot(500 grams)' 'Porota'
#  'Faluda' 'Matha(1 litre)' 'Rupchada Fish kabab' 'Beef sik kabab'
#  'Mutton Boti Kabab' 'Chicken boti kabab' 'Chicken Grill' 'Chicken Tikka'
#  'Chicken Resmi Kabab' 'Chicken kashmeri Kabab' 'Mutton khiri kabab'
#  'Beef chap' 'Beef roll' 'Kacci Biriyani' 'Chicken Biriyani'
#  'Mutton vuna khicuri' 'Mutton Tehari' 'double_beef_cheddar'
#  'fat_mamba_burger' 'chicke_cheddar_burger' 'beef_cheddar_blust'
#  'chicklen_premium_burger' 'beef_cheddar_burger' 'choco_cold_coffee'
#  'cold_strawberry' 'tangy_lemon_soda' 'hot_peri_peri_wings'
#  'truffle_wings' 'chicken_momo' 'spicy_chicken' 'chicken_cheese_nuggets'
#  'masala_wedges' 'hot_fries' 'truffle_fries' 'big_herfy_burger'
#  'grilled_chicken_burger' 'chill_chicken_burger' 'crispy_juicy_burger'
#  'veggle_burger' 'turkish_burger' 'chicken_nugets' 'fried_chicken'
#  'best_burger' 'supreme_burger' 'grill_burger' 'spicy_mustard_burger'
#  'brioche_burger' 'juicy_burger' 'spicy_burger' 'juicy_cheese_burger'
#  'hot_wings' 'bbq_hot_wings' 'Tandoori Zinger' 'Texas BBQ zinger'
#  'Moroccan Zinger' 'Mexican Zinger' 'Kashundi Zinger' '1pc hot & crispy'
#  '2pc hot & crispy' '4pc hot & crispy' '4pc Chicken & fries meal'
#  '6pc boneless strips' 'chicken burger' 'naga_chicken_burher'
#  'bbq_fried_chicken' 'mixed_pasta' 'special_pasta'
#  'chicken_pepperoni_pizza' 'chicken_sausage_pizza'
#  'food_terminal_special_pizza' 'bbq_wings' 'baked_chicken_alfredo'
#  'alfredo_pasta' 'spicy_pasta' 'pasta_italiano' 'chicken_naga_pasta'
#  'italian_special_pizza' '4_flavor_pizza' 'mexican_hot_pizza'
#  'baby_cream_pizza' 'food_plate_love_pizza' 'italian_pasta'
#  'mexiacan_hot_pasta' 'pan_pasta' 'cream_pan_pasta' 'naga_bbq_hot_wings'
#  'bbq_nachos' 'chicken_lilipop' 'garlic_chicken_fry'
#  'chicken_buffalo_hot_wings' 'stick_wonton' 'bbq_chicken_cheese_burger'
#  'mexican_beef_burger' 'chicken_juicy_burger'
#  'double_decker_chicken_burger' 'teen_lecker_burger'
#  'cheese_lecker_burger' 'supreme_chicken_burgerf' 'zan_thanda'
#  'smocky_chicken' 'chicken_nachos' 'meat_box' 'smokey_meat_box'
#  'smoky_wings' 'crispy_wings' 'smoky_fried_chicken' 'cheesy_alfredo_pizza'
#  'chicken_keema_pizza' 'chicken_cheese_pasta' 'chicken_bbq_pasta'
#  'spicy_chicken_bbq_pasta' 'naga_chicken_pasta' 'cheesy_sausage_pasta'
#  'beef_cheese_pasta' 'sausage_fantasy_pizza' 'spicy_naga_chicken_pizza'
#  'chicken_cheese_pizza' 'classic_margarita_pizza' 'Strips box'
#  'Got wings box' 'Popcorn box' 'Super Charger box' 'Smoky Red Rice Bowl'
#  'Hot & Crispy Rice Bowl' 'Hot wings Rice Bowl' 'Popcorn Rice bowl'
#  'Chicken & Rice Meal' 'Rice box' '2 Pcs Chicken & Rice Meal'
#  'Strips & Rice Combo' 'Gravy' '2 pcs Smoky Red Chicken'
#  '1 pc Hot & Crispy' 'Rizo Rice' 'Fries Medium ' 'Fries Large'
#  'Tangy-Fries Medium ' 'Tangy-Fries Large' 'Potato Wedges'
#  'Beef Sheek Kabab' 'Tandoori Chicken Kabab' 'Chicken Achari Kabab'
#  'Chicken Hariyali Kabab' 'BBQ Chicken' 'Alu Paratha' 'Butter Paratha'
#  'Kashmiri Paratha' 'Shahi Paratha' 'Kabab pora special Paratha'
#  'Plain Nan' 'Butter Nan' 'Garlic Nan' 'Garlic Cheese Nan'
#  'Garlic extra Cheese Nan' 'Arabian Nan' 'Garlic Chili Nan'
#  'Special kabab pora Nan' 'Special Nan' 'Chicken roast' 'Rui fish curry'
#  'Cheesy Chicken Pizza' 'Grilled chicken with mushroom pizza'
#  'bbq chicken pizza' 'Alfredo with chicken pizza' 'pepperoni pizza'
#  'roasted beef picture' 'chicken sausage pizza' 'seafood pizza'
#  'mexicano chicken pizza' 'mexicano beef pizza' 'chicken pineapple pizza'
#  'Bolognese pizza' 'Philly stake  pizza chicken '
#  'Philly stake Pizza beef' 'Meatball pizza ' 'blend special pizza'
#  'crispy_chicken' 'wonton' 'wedges' 'cheese_delight_burger'
#  'cheese_blast_burger' 'six_patty_burger' 'wings' 'chicken_sausage_pasta'
#  'bbq_chicken_pasta' 'maxican_oven_pasta' 'meat_lovers_pizza'
#  'mashroom_pizza' 'supreme_pizza' 'festival_pizza' 'cheddar_pizza'
#  'chicken_clear_soup' 'vagetable_clear_soup' 'chittagfong_pizza'
#  'neples_unique' 'premium_pizza']
# ['Shopnar Shopno' 'Star Kabab & Restaurant' "Sultan's dine" 'Kacchi Bhai'
#  'Burger King' 'burger King' 'Haji Biriyani' 'PizzaBurg' 'pizzaBurg'
#  'Magpie Restaurant' 'KFC' 'BurgerX' 'Takeout' 'Pizza Hut' 'Burger Xpress'
#  '3 Food' 'Street Oven' 'Le Delicia' 'Chillox' 'Alfresco' 'Pizza Inn'
#  'Barcode Cafe' 'Bangaliana Bhoj' 'Dokhina Kitchen' "Khana's" 'Herfy'
#  'BFC' 'Le Metro' 'Food Terminal' 'Food Plate' 'Lecker' 'Pizza Best'
#  'Kabab Pora Restaurant' 'American blend pizzas'
#  'Food Chemistry Rooftop Cafe']
# ['Shewrapara' 'Banani' 'Bashundhara R/A' 'Mirpur' 'Khilgaon'
#  'Shonir Akhra' 'Elephant Road' 'Gulshan' 'Ibrahimpur']
# ['local' 'biriyani' 'dessert' 'beverage' 'burger' 'burrito' 'salad'
#  'fast_food' 'pizza' 'kabab' 'pasta' 'soup' 'shawarma' 'chowmine'
#  'main_course' 'side' 'Biriyani' 'curry' 'rice' 'Drinks' 'beef' 'patato'
#  'khicuri' 'Shakes' 'shakes' 'pastra' 'set_meal' 'set meal' 'snacks'
#  'paratha' 'naan' 'b']
# ['beef' 'egg' 'flour' 'chicken' 'mutton' 'rice' 'yogurt' 'fish' 'potato'
#  'sea_food' 'beverage' 'dal' 'ruti' 'baji' 'vorta' 'dessert' 'cold_coffee'
#  'prawn' 'beef_chicken' 'chocolate' 'cheese' 'ice_cream' 'vanilla' 'fruit'
#  'soft_drink' 'coffee' 'tea' 'duck' 'fush' 'meat' 'bevarage' 'lemon_soda'
#  'chickne' 'soft_drinks' 'Chicken' 'curry' 'Beef' 'chiciken' 'chciken']

# %% [markdown]
# Numeric data points

# %%
for i in number_col.columns:
  if i!='food_price':
    print(i)
    print("Skewness: ", round(df[i].skew(),3))

    ### ploting the column

    plt.figure(figsize=(13,5))
    plt.subplot(1,2,1)
    sns.violinplot(df[i])
    plt.ylabel('count')
    plt.subplot(1,2,2)
    sns.boxplot(x=df[i])
    plt.show()
# Out:
# rating
# Skewness:  -0.725

# %%
categoric_col.head()
# Out:
#                 food_name                   vendor         location  \
# 0              beef_bhuna           Shopnar Shopno       Shewrapara
# 1               egg_omlet           Shopnar Shopno       Shewrapara
# 2            special_naan  Star Kabab & Restaurant           Banani
# 3  deshi_chicken_jhal_fry  Star Kabab & Restaurant           Banani
# 4          basmati_kacchi            Sultan's dine  Bashundhara R/A
#
#   cuisine_type main_ingridinet
# 0        local            beef
# 1        local             egg
# 2        local           flour
# 3        local         chicken
# 4     biriyani          mutton

# %% [markdown]
# food_name

# %%
labels, counts = np.unique(df.food_name, return_counts=True)
plt.figure(figsize=(10,10))
plt.pie(counts,autopct='%1.1f', labels=labels, pctdistance=1, shadow=True, counterclock=True)
plt.title('Categorical food_name data')
plt.show()

# %% [markdown]
# vendor

# %%
labels, counts = np.unique(df.vendor, return_counts=True)
print(labels)
plt.figure(figsize=(12,12))
plt.pie(counts,autopct='%1.1f', labels=labels, pctdistance=0.7, shadow=True, counterclock=True)
plt.title('Categorical vendor data')
plt.show()
# Out:
# ['3 Food' 'Alfresco' 'American blend pizzas' 'BFC' 'Bangaliana Bhoj'
#  'Barcode Cafe' 'Burger King' 'Burger Xpress' 'BurgerX' 'Chillox'
#  'Dokhina Kitchen' 'Food Chemistry Rooftop Cafe' 'Food Plate'
#  'Food Terminal' 'Haji Biriyani' 'Herfy' 'KFC' 'Kabab Pora Restaurant'
#  'Kacchi Bhai' "Khana's" 'Le Delicia' 'Le Metro' 'Lecker'
#  'Magpie Restaurant' 'Pizza Best' 'Pizza Hut' 'Pizza Inn' 'PizzaBurg'
#  'Shopnar Shopno' 'Star Kabab & Restaurant' 'Street Oven' "Sultan's dine"
#  'Takeout' 'burger King' 'pizzaBurg']

# %% [markdown]
# location

# %%
labels, counts = np.unique(df.location, return_counts=True)
print(labels)
plt.figure(figsize=(10,10))
plt.pie(counts,autopct='%1.1f', labels=labels, pctdistance=1, shadow=True, counterclock=True)
plt.title('Categorical location data')
plt.show()
# Out:
# ['Banani' 'Bashundhara R/A' 'Elephant Road' 'Gulshan' 'Ibrahimpur'
#  'Khilgaon' 'Mirpur' 'Shewrapara' 'Shonir Akhra']

# %% [markdown]
# cuisin_type

# %%
labels, counts = np.unique(df.cuisine_type, return_counts=True)
print(labels)
plt.figure(figsize=(10,10))
plt.pie(counts,autopct='%1.1f', labels=labels, pctdistance=1, shadow=True, counterclock=True)
plt.title('Categorical cuisine_type data')
plt.show()
# Out:
# ['Biriyani' 'Drinks' 'Shakes' 'b' 'beef' 'beverage' 'biriyani' 'burger'
#  'burrito' 'chowmine' 'curry' 'dessert' 'fast_food' 'kabab' 'khicuri'
#  'local' 'main_course' 'naan' 'paratha' 'pasta' 'pastra' 'patato' 'pizza'
#  'rice' 'salad' 'set meal' 'set_meal' 'shakes' 'shawarma' 'side' 'snacks'
#  'soup']

# %% [markdown]
# main ingredient

# %%
labels, counts = np.unique(df.main_ingridinet, return_counts=True)
print(labels)
plt.figure(figsize=(10,10))
plt.pie(counts,autopct='%1.1f', labels=labels, pctdistance=2, shadow=True, counterclock=True)
plt.title('Categorical main_ingridient data')
plt.show()
# Out:
# ['Beef' 'Chicken' 'baji' 'beef' 'beef_chicken' 'bevarage' 'beverage'
#  'chciken' 'cheese' 'chiciken' 'chicken' 'chickne' 'chocolate' 'coffee'
#  'cold_coffee' 'curry' 'dal' 'dessert' 'duck' 'egg' 'fish' 'flour' 'fruit'
#  'fush' 'ice_cream' 'lemon_soda' 'meat' 'mutton' 'potato' 'prawn' 'rice'
#  'ruti' 'sea_food' 'soft_drink' 'soft_drinks' 'tea' 'vanilla' 'vorta'
#  'yogurt']

# %%
labels, counts = np.unique(df.main_ingridinet, return_counts=True)
plt.figure(figsize=(50,10))
plt.bar(labels, counts, color ='maroon',
        width = 0.4)
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title('Categorical main_ingridient data')
plt.show()

# %%
df.shape
# Out:
# (699, 7)

# %% [markdown]
# Label encoding

# %%
label_data = df.copy()

# %% [markdown]
# applying label encoder to each categorical data columns

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
label_encoder = LabelEncoder()
for col in categoric_col:
  label_data[col] = label_encoder.fit_transform(label_data[col])

# %%
label_data.head(10)
# Out:
#    food_name  rating  food_price  vendor  location  cuisine_type  \
# 0        141     3.9         229      28         7            15
# 1        309     3.9          57      28         7            15
# 2        501     4.3          30      29         0            15
# 3        297     4.3         140      29         0            15
# 4        124     4.3         460      31         1             6
# 5        406     4.3         299      31         1             6
# 6        415     4.3         230      31         1             6
# 7        159     4.3         200      31         1            15
# 8        241     4.3         150      31         1            15
# 9        357     4.3          60      31         1            15
#
#    main_ingridinet
# 0                3
# 1               19
# 2               21
# 3               10
# 4               27
# 5               10
# 6               27
# 7                3
# 8               10
# 9                3

# %% [markdown]
# correlation matrix

# %%
corrmat =  label_data.corr()
corrmat
# Out:
#                  food_name    rating  food_price    vendor  location  \
# food_name         1.000000  0.001412    0.109419 -0.033853  0.117388
# rating            0.001412  1.000000    0.057736  0.217530 -0.448219
# food_price        0.109419  0.057736    1.000000 -0.105871 -0.175482
# vendor           -0.033853  0.217530   -0.105871  1.000000 -0.267032
# location          0.117388 -0.448219   -0.175482 -0.267032  1.000000
# cuisine_type      0.078585 -0.026212    0.321801  0.069006 -0.137218
# main_ingridinet   0.060630 -0.073177   -0.219826  0.000181 -0.056050
#
#                  cuisine_type  main_ingridinet
# food_name            0.078585         0.060630
# rating              -0.026212        -0.073177
# food_price           0.321801        -0.219826
# vendor               0.069006         0.000181
# location            -0.137218        -0.056050
# cuisine_type         1.000000         0.011730
# main_ingridinet      0.011730         1.000000

# %%
cmap = sns.diverging_palette(70, 20, s = 50, l = 40, n = 6, as_cmap = True)
f, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corrmat, cmap=cmap, annot=True)
plt.show()

# %% [markdown]
# X = features and y = label

# %%
X = label_data.drop(["food_price","food_name"], axis = 1)
y = label_data["food_price"]

# %% [markdown]
# **Train-Test Spliting**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, shuffle=True)

# %% [markdown]
# Importing regression models

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline

# %% [markdown]
# Initializing the models

# %%
# linear regression
pipeline_lr = ([("scalar1", StandardScaler()), ("lr_classifier", LinearRegression())])

# Decision tree
pipeline_dt = ([("scalar2", StandardScaler()), ("dt_classifier", DecisionTreeRegressor())])

# Random forest
pipeline_rf = ([("scalar3", StandardScaler()), ("rf_classifier", RandomForestRegressor())])

# k nearest neighbor
pipeline_kn = ([("scalar4", StandardScaler()), ("kn_classifier", KNeighborsRegressor())])

# XG boost
pipeline_xgb = ([("scalar5", StandardScaler()), ("xgb_classifier", XGBRegressor())])

# %%
# pipeline list
pipelines = [pipeline_lr,pipeline_dt,pipeline_rf,pipeline_kn,pipeline_xgb]

# dict of pipelines and model types
pipe_dict = {0:"LinearRegression", 1:"DecisionTree", 2:"RandomForest", 3:"KNearestNeighbors", 4:"XGBoost"}

for pipe in pipelines:
  pipe_object = Pipeline(pipe)
  pipe_object.fit(X_train, y_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
# cross validation score
cv_result_rms = []

for i, pipeline in enumerate(pipelines):
    pipe_object = Pipeline(pipeline)  # Wrap the pipeline in Pipeline class
    cv_score = cross_val_score(pipe_object, X_train, y_train, scoring="neg_root_mean_squared_error")
    cv_result_rms.append(cv_score)
    print(f"{pipe_dict[i]}, {cv_score.mean()}")
# Out:
# LinearRegression, -201.858540562679
# DecisionTree, -143.3836112413174
# RandomForest, -137.23887904975754
# KNearestNeighbors, -162.21205667187314
# XGBoost, -138.4554179250892

# %%
cv_result_rms
# Out:
# [array([-204.90125508, -279.56199634, -162.50694682, -173.6031642 ,
#         -188.71934037]),
#  array([-139.40565009, -216.37838285, -104.42528882, -124.62716137,
#         -132.08157308]),
#  array([-133.06541314, -201.96595285, -110.18860505, -121.31694717,
#         -119.65747705]),
#  array([-167.76128619, -224.20724427, -133.23752796, -147.5725823 ,
#         -138.28164264]),
#  array([-133.54324961, -206.59424154, -110.38256344, -120.43188147,
#         -121.32515356])]

# %%
# !pip install lazypredict

# %%
# from lazypredict.Supervised import LazyRegressor

# %%
# # fit lazyregressor

# reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
# models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# print(models)

# %% [markdown]
# Linear Regression

# %%
pipe_lr = Pipeline(pipeline_lr)
pred_lr = pipe_lr.predict(X_test)

# %% [markdown]
# Linear Regressor Model Evaluation

# %%
print("Linear Regressor Model Evaluation")
print("R^2: ", metrics.r2_score(y_test, pred_lr))
print("Adjust R^2: ", 1-(1-metrics.r2_score(y_test,pred_lr))*(len(y_test)-1)/(len(y_test)))
print("MAE: ", metrics.mean_absolute_error(y_test,pred_lr))
print("MSE: ", metrics.mean_squared_error(y_test,pred_lr))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,pred_lr)))
# Out:
# Linear Regressor Model Evaluation
# R^2:  0.2175430126075958
# Adjust R^2:  0.22201419539269518
# MAE:  158.42713316006507
# MSE:  49448.61565407692
# RMSE:  222.37044689903584

# %%
# Data

print("Actual Data: ")
print(y_test)
print("predicted data by linear regression: ")
print(pred_lr)
# Out:
# Actual Data:
# 158    109
# 499    399
# 396    690
# 155    259
# 321    225
#       ...
# 617    179
# 578    270
# 231    100
# 336    165
# 655    650
# Name: food_price, Length: 175, dtype: int64
# predicted data by linear regression:
# [170.40518106 268.1491677  483.58491581 226.65005679 318.95310717
#  408.14814586 295.79287328 390.10782277 358.91510712 400.01159282
#  335.67038806 106.24443264 368.39719726 287.92956192 315.32601521
#  167.39825421 263.88288688 314.12409738 312.73694307 465.9171022
#  400.01159282 226.50302723 262.88738489 244.66944225 328.22261206
#  172.38665966 287.97742336 380.8255434  283.69192882 251.68434705
#  275.20869666 222.70152312 226.4774124  345.30250464 296.70537361
#  246.05679158 258.06671846 330.06793147 295.70537071 275.20869666
#  296.70537361 324.0071403  311.22860002 211.3502964  419.69899729
#  315.32601521 210.89952548 400.01159282 269.89077273 337.58826766
#  368.81887717 263.877843   379.609197   171.81934557 266.95247329
#  302.33937119 479.82829459 254.6148655  311.22860002 210.89952548
#  308.43528818 400.01159282 167.39825421 366.09764841 358.93416182
#  330.84972163 251.68434705 422.91605151 178.37397456 335.67038806
#   94.21857318 249.30022272 251.68434705 215.77440516 324.32178584
#  483.58491581 210.89952548 465.9171022  379.18441547 421.30053841
#  368.39719726 337.88338139 577.16306275 514.87868535 275.20869666
#  372.87603343 395.16531156 463.39104652 248.30599088 168.61708945
#  539.95759189 483.58491581 485.19401016 326.89131069 276.84982459
#  295.70537071 479.82829459 283.69192882 304.17242704 254.6148655
#  324.32178584 254.6148655  320.13702711 150.59107474 266.95247329
#  298.16893632 300.29385028 265.31134536 306.60272491 350.52579629
#  353.31910813 362.03848902  96.27998782 197.73561597 362.04243727
#  298.78580982 483.58491581 268.1491677  294.90138825 295.49775955
#  231.73254763 400.01159282 251.68434705 483.58491581 400.01159282
#  372.11057814 210.89952548 287.97742336 302.33937119 308.43528818
#  221.78733489 483.58491581 248.54108935 361.7173859  222.92236754
#  181.76614653 251.68434705 246.05679158 483.6859697  281.91663219
#  197.73561597 307.77088677 251.68434705 206.07885905 362.04243727
#  358.91510712 258.06671846 304.17242704 295.79287328 343.61502866
#  311.22860002 353.31910813 246.27086033 317.3248196  380.8255434
#  252.18456763 577.16306275 308.43528818 296.70537361 401.00561523
#  483.58491581 106.24443264  79.62355839 226.63065306 315.32601521
#  172.38665966 221.32573462 211.3502964  222.74623149 400.01159282
#  399.27465459 211.3502964  251.68434705 172.38665966 521.9188027 ]

# %%
# Plotting the actual data and predicted data
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Data')
plt.scatter(range(len(pred_lr)), pred_lr, color='red', label='Predicted Data')
plt.xlabel('Data Points')
plt.ylabel('Target Variable')
plt.title('Actual Data vs. Predicted Data for linear regression')
plt.legend()
plt.show()

# %% [markdown]
# Decission Tree

# %%
pipe_dt = Pipeline(pipeline_dt)
pred_dt = pipe_dt.predict(X_test)

# %% [markdown]
# Decision Tree Evaluation

# %%
print("R^2: ", metrics.r2_score(y_test, pred_dt))
print("Adjust R^2: ", 1-(1-metrics.r2_score(y_test,pred_dt))*(len(y_test)-1)/(len(y_test)))
print("MAE: ", metrics.mean_absolute_error(y_test,pred_dt))
print("MSE: ", metrics.mean_squared_error(y_test,pred_dt))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,pred_dt)))
# Out:
# R^2:  0.6335918149254784
# Adjust R^2:  0.6356855759830471
# MAE:  89.6129202226345
# MSE:  23155.748888688096
# RMSE:  152.17013139472573

# %%
# Data

print("Actual Data: ")
print(y_test)
print("predicted data by Decision Tree: ")
print(pred_dt)
# Out:
# Actual Data:
# 158    109
# 499    399
# 396    690
# 155    259
# 321    225
#       ...
# 617    179
# 578    270
# 231    100
# 336    165
# 655    650
# Name: food_price, Length: 175, dtype: int64
# predicted data by Decision Tree:
# [ 99.         399.         856.         219.         270.
#  511.83333333 348.         403.33333333 310.         842.92857143
#  283.         235.         391.66666667  23.         511.83333333
#  140.         110.         315.66666667 141.         352.33333333
#  842.92857143 240.         179.6        386.66666667 338.33333333
#  205.         369.         301.66666667 359.         115.33333333
#  152.          34.         187.         182.         307.27272727
#  440.         209.         369.         268.         152.
#  307.27272727 154.         303.75       187.2        650.
#  511.83333333 220.         842.92857143  28.         414.
#  439.4        296.4        440.          57.         305.
#  145.71428571 650.         219.         303.75       220.
#  449.         842.92857143 140.         212.66666667 318.
#  288.         115.33333333 325.         166.         283.
#  235.         195.         115.33333333 285.         242.
#  856.         220.         352.33333333 553.         500.
#  391.66666667 285.         246.42857143 193.75       152.
#  366.66666667 325.         780.         599.         135.
#  650.         856.         269.         195.         110.
#  268.         650.         359.          76.66666667 219.
#  242.         219.         315.66666667 130.         305.
#  200.         299.         242.         225.         599.
#  313.75        70.         460.          57.         458.
#  690.         856.         399.         237.5        414.
#  292.33333333 842.92857143 115.33333333 856.         842.92857143
#   46.         220.         369.         145.71428571 449.
#  285.         856.         301.66666667  70.         116.
#   70.         115.33333333 440.         210.          23.
#   57.         399.         115.33333333 228.         458.
#  310.         209.          76.66666667 348.         100.
#  303.75       313.75       440.         325.         301.66666667
#  215.         246.42857143 449.         307.27272727 357.5
#  856.         235.         594.         385.         511.83333333
#  205.         300.         187.2        130.         842.92857143
#  182.33333333 187.2        115.33333333 205.         650.        ]

# %%
# Plotting the actual data and predicted data
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Data')
plt.scatter(range(len(pred_dt)), pred_dt, color='red', label='Predicted Data')
plt.xlabel('Data Points')
plt.ylabel('Target Variable')
plt.title('Actual Data vs. Predicted Data for Decision Tree')
plt.legend()
plt.show()

# %% [markdown]
# Random Forest

# %%
pipe_rf = Pipeline(pipeline_rf)
pred_rf = pipe_rf.predict(X_test)

# %% [markdown]
# Random Forest Model Evaluation

# %%
print("R^2: ", metrics.r2_score(y_test, pred_rf))
print("Adjust R^2: ", 1-(1-metrics.r2_score(y_test,pred_rf))*(len(y_test)-1)/(len(y_test)))
print("MAE: ", metrics.mean_absolute_error(y_test,pred_rf))
print("MSE: ", metrics.mean_squared_error(y_test,pred_rf))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,pred_rf)))
# Out:
# R^2:  0.6736961535780356
# Adjust R^2:  0.6755607469861611
# MAE:  84.49934236332399
# MSE:  20621.29132738485
# RMSE:  143.60115364224916

# %%
# Data

print("Actual Data: ")
print(y_test)
print("predicted data by random Forest: ")
print(pred_rf)
# Out:
# Actual Data:
# 158    109
# 499    399
# 396    690
# 155    259
# 321    225
#       ...
# 617    179
# 578    270
# 231    100
# 336    165
# 655    650
# Name: food_price, Length: 175, dtype: int64
# predicted data by random Forest:
# [118.56333333 393.85333333 849.77515945 219.61666667 278.32916667
#  481.20390765 353.31243146 400.85571429 319.75386724 828.90686789
#  282.69652381 227.01740995 389.97332251  44.428      499.50151046
#  161.83280952 110.8        295.01380952 143.79622403 359.50986291
#  828.90686789 230.54465201 177.24035029 379.04513709 306.41670822
#  208.72307055 369.96234848 309.64095238 359.38333333 115.29574137
#  160.30889394 106.80333333 173.02654762 187.64340476 310.30309628
#  364.70688889 211.68035187 359.62530664 270.84203571 160.30889394
#  310.30309628 157.37842857 310.77583333 186.97407143 645.15
#  499.50151046 225.79276557 828.90686789  96.27942857 413.85
#  438.62743651 298.1310974  391.685       95.635      274.34694444
#  143.86742299 650.         220.13659257 310.77583333 225.79276557
#  447.64860723 828.90686789 161.83280952 204.39483333 317.55647161
#  287.41647619 115.29574137 324.14190476 176.83430952 282.69652381
#  224.91740995 201.91310317 115.29574137 220.66816667 241.58632937
#  849.77515945 225.79276557 359.50986291 567.90854037 525.84666667
#  389.97332251 282.69083333 246.97513278 194.86638889 160.30889394
#  372.55387807 331.72853175 664.62       576.73049784 153.65083333
#  661.1        849.77515945 309.15       189.61696429 147.06719048
#  270.84203571 650.         359.38333333  81.6647619  220.13659257
#  241.58632937 220.13659257 295.01380952 159.26       274.34694444
#  218.82280556 270.76233333 267.54727697 220.80457143 541.51304473
#  315.23708333 150.95310606 384.91833333  91.825      458.47715729
#  520.71061328 849.77515945 393.85333333 246.7075     414.065
#  223.57833333 828.90686789 115.29574137 849.77515945 828.90686789
#   52.11583333 225.79276557 369.96234848 143.86742299 447.64860723
#  273.323      849.77515945 306.64095238 150.95310606 119.04466667
#   81.75927739 115.29574137 364.70688889 228.51321429  48.29107692
#   91.825      291.80886508 115.29574137 226.85711111 458.47715729
#  319.75386724 211.68035187  81.6647619  353.31243146 146.77408333
#  310.77583333 315.23708333 350.89888889 327.63293651 309.64095238
#  228.04324315 246.97513278 447.64860723 310.30309628 358.6675
#  849.77515945 227.01740995 390.89404762 385.18152778 499.50151046
#  208.72307055 309.14383333 186.97407143 139.935      828.90686789
#  181.30714286 186.97407143 115.29574137 208.72307055 661.1       ]

# %%
# Plotting the actual data and predicted data
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Data')
plt.scatter(range(len(pred_rf)), pred_rf, color='red', label='Predicted Data')
plt.xlabel('Data Points')
plt.ylabel('Target Variable')
plt.title('Actual Data vs. Predicted Data for random forest')
plt.legend()
plt.show()

# %% [markdown]
# K Nearest Neighbor

# %%
pipe_kn = Pipeline(pipeline_kn)
pred_kn = pipe_kn.predict(X_test)

# %% [markdown]
# K Nearest Neighbor Model Evaluation

# %%
print("R^2: ", metrics.r2_score(y_test, pred_kn))
print("Adjust R^2: ", 1-(1-metrics.r2_score(y_test,pred_kn))*(len(y_test)-1)/(len(y_test)))
print("MAE: ", metrics.mean_absolute_error(y_test,pred_kn))
print("MSE: ", metrics.mean_squared_error(y_test,pred_kn))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,pred_kn)))
# Out:
# R^2:  0.570905941415423
# Adjust R^2:  0.5733579074644777
# MAE:  99.72457142857145
# MSE:  27117.28251428571
# RMSE:  164.67325986414951

# %%
# Data

print("Actual Data: ")
print(y_test)
print("predicted data by k nearest neighbor: ")
print(pred_kn)
# Out:
# Actual Data:
# 158    109
# 499    399
# 396    690
# 155    259
# 321    225
#       ...
# 617    179
# 578    270
# 231    100
# 336    165
# 655    650
# Name: food_price, Length: 175, dtype: int64
# predicted data by k nearest neighbor:
# [149.8 383.  814.  194.  314.  755.  348.  366.  366.  755.  311.8 188.
#  404.  215.4 544.  156.  118.  221.4 147.8 357.  755.  299.  179.6 389.
#  304.  189.  327.  483.  383.  110.  229.8 383.  224.  173.2 332.  193.6
#  187.2 293.  330.4 229.8 332.  164.  333.  187.2 650.  544.  463.2 755.
#  256.4 377.  439.4 296.4 324.4 134.4 196.8 162.2 650.  220.  333.  463.2
#  391.  755.  156.  146.  318.  328.  110.  448.8 224.  311.8 309.  296.4
#  110.  177.4 242.  814.  463.2 357.  357.4 430.  404.  285.  253.  197.
#  229.8 330.  338.  447.  399.  180.  677.  814.  697.8 194.6 144.2 330.4
#  650.  383.  137.6 220.  242.  220.  221.4 309.  196.8 220.  399.  221.2
#  200.  433.  341.  283.8 225.  143.6 452.8 276.  814.  383.  288.  350.6
#  141.6 755.  110.  814.  755.   98.2 463.2 327.  162.2 391.  180.4 814.
#  153.6 255.6 139.2 196.  110.  193.6 197.  215.4 143.6 285.  110.  177.6
#  452.8 366.  187.2 137.6 348.  208.6 333.  341.  223.8 315.  483.  271.4
#  253.  391.  332.  454.  814.  188.  508.4 393.  544.  189.  149.8 187.2
#  262.  755.  165.  187.2 110.  189.  677. ]

# %%
# Plotting the actual data and predicted data
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Data')
plt.scatter(range(len(pred_kn)), pred_kn, color='red', label='Predicted Data')
plt.xlabel('Data Points')
plt.ylabel('Target Variable')
plt.title('Actual Data vs. Predicted Data for k nearest neighbor')
plt.legend()
plt.show()

# %% [markdown]
# XGBoost

# %%
pipe_xgb = Pipeline(pipeline_xgb)
pred_xgb = pipe_xgb.predict(X_test)

# %% [markdown]
# XGB Regressor Model Evaluation

# %%
print("R^2: ", metrics.r2_score(y_test, pred_xgb))
print("Adjust R^2: ", 1-(1-metrics.r2_score(y_test,pred_xgb))*(len(y_test)-1)/(len(y_test)))
print("MAE: ", metrics.mean_absolute_error(y_test,pred_xgb))
print("MSE: ", metrics.mean_squared_error(y_test,pred_xgb))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,pred_xgb)))
# Out:
# R^2:  0.6650433190247338
# Adjust R^2:  0.6669573572017353
# MAE:  85.35589195251465
# MSE:  21168.12098963944
# RMSE:  145.49268362924454

# %%
# Data

print("Actual Data: ")
print(y_test)
print("predicted data by xgboost regressor: ")
print(pred_xgb)
# Out:
# Actual Data:
# 158    109
# 499    399
# 396    690
# 155    259
# 321    225
#       ...
# 617    179
# 578    270
# 231    100
# 336    165
# 655    650
# Name: food_price, Length: 175, dtype: int64
# predicted data by xgboost regressor:
# [ 99.00044  398.5865   856.04895  218.33035  271.8852   475.61404
#  346.82382  402.93814  310.99976  842.86273  282.60376  234.3609
#  391.6353    23.383095 511.48965  148.93845  108.68204  291.80066
#  141.33388  352.5399   842.86273  240.26146  179.5425   371.73578
#  349.71973  205.0001   368.57687  301.72012  360.44168  115.20291
#  159.35735  114.42516  187.36214  188.12921  307.4303   384.91507
#  208.93318  383.99472  267.26022  159.35735  307.4303   158.86292
#  304.01395  186.69708  617.79156  511.48965  219.85545  842.86273
#   29.407148 413.73346  439.6139   295.99094  435.6325    60.43678
#  303.98502  145.84546  649.82605  218.93835  304.01395  219.85545
#  449.79742  842.86273  148.93845  210.29991  317.86557  288.2226
#  115.20291  324.8882   166.16972  282.60376  225.77985  186.74239
#  115.20291   99.703285 241.77103  856.04895  219.85545  352.5399
#  552.5831   506.8149   391.6353   285.48828  246.33235  193.66147
#  159.35735  366.0487   303.85248  775.75165  598.2158   102.22027
#  678.10095  856.04895  269.9328   193.34842  151.25063  267.26022
#  649.82605  360.44168   78.12592  218.93835  241.77103  218.93835
#  314.9436   162.34679  303.98502  251.01192  299.08408  308.14792
#  224.74702  594.80304  313.62283   65.89738  459.74124   58.123077
#  457.74756  688.04596  856.04895  398.5865   237.44855  414.4496
#  195.86378  842.86273  115.20291  856.04895  842.86273   46.516426
#  219.85545  368.57687  145.84546  449.79742  283.16672  856.04895
#  256.335     53.522648 116.80596   71.35511  115.20291  384.91507
#  209.99652   54.323032  58.123077 312.7266   115.20291  228.93039
#  457.74756  310.99976  208.93318   78.12592  346.82382  147.75374
#  304.01395  313.62283  437.37506  323.79007  301.72012  182.56349
#  246.33235  449.79742  307.4303   357.8147   856.04895  234.3609
#  348.90613  385.23465  511.48965  205.0001   284.11377  186.69708
#  129.77324  842.86273  181.95906  186.69708  115.20291  205.0001
#  650.8213  ]

# %%
# Plotting the actual data and predicted data
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual Data')
plt.scatter(range(len(pred_xgb)), pred_xgb, color='red', label='Predicted Data')
plt.xlabel('Data Points')
plt.ylabel('Target Variable')
plt.title('Actual Data vs. Predicted Data for xgboost regressor')
plt.legend()
plt.show()
